# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import math
import numpy
# входные данные вариант 7
k = 0.27
T = 2
γ_g = 0.01

α = [0, 2, 5]
γ = [0.1, 0.5, 1, 10, 100]

# %%
x = np.linspace(-30, 30, 10000)
i = 0
j = 0
φ = lambda ωs: -np.arctan(ωs / γ[i]) - ωs * T - α[j]/2 * np.log( (1 + (ωs / γ[i])**2 ) / k )
dφ = lambda ωs: - (γ[i] + α[j] * ωs) / (γ[i]**2 +  ωs**2) - T
g0 = lambda ωs: np.log( (1 + (ωs / γ[i])**2 ) / k )

φ_ωs = φ(x) 
    



plt.plot(x, φ(x), label='φ(x)')

plt.xlabel("ωs")
plt.ylabel("φ(ωs)")
plt.grid(True)

# %%
plt.plot(φ(x), x, label='φ(x)')

plt.xlabel("φ(ωs)")
plt.ylabel("ωs")

plt.grid(True)

# %%
g0_φ = []

j = 0
i = 0
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
i = 1
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
i = 2
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
i = 3
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
i = 4
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))


plt.xlabel("φ")
plt.ylabel("g0(φ)")
plt.legend()

plt.xlim([-20,20])
plt.grid(True)

# %%
j = 1
i = 0
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
i = 1
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
i = 2
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
i = 3
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
i = 4
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))


plt.xlabel("φ")
plt.ylabel("g0(φ)")
plt.legend()

plt.xlim([-20,20])
plt.grid(True)

# %%
j = 2
i = 0
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
i = 1
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
i = 2
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
i = 3
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
i = 4
plt.plot(φ(x), g0(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))

plt.xlabel("φ")
plt.ylabel("g0(φ)")
plt.legend()

plt.xlim([-20,20])
plt.grid(True)

# %%
g0_φ = []
g0_ = -4 * np.log(k)
Es_2 = lambda ωs: (g0_ - np.log( 1 + (ωs/γ[i])**2)/k ) / ( ( 1 + (ωs/γ[i])**2)/k - 1)
j = 0
i = 0
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 1
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 2
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 3
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 4
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )

plt.xlabel("φ")
plt.ylabel("E^2(φ)")
plt.legend()

plt.xlim([-20,20])
plt.grid(True)

# %%
j = 1
i = 0
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 1
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 2
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 3
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 4
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )

plt.xlabel("φ")
plt.ylabel("E^2(φ)")
plt.legend()
plt.xlim([-20,20])
plt.grid(True)

# %%
j = 2
i = 0
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 1
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 2
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 3
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 4
plt.plot(φ(x), Es_2(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )


plt.xlabel("φ")
plt.ylabel("E^2(φ)")
plt.legend()
plt.xlim([-20,20])
plt.grid(True)

# %%
x = np.linspace(-10, 10, 10000)
j = 0
i = 0

plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 1
plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 2
plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 3
plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 4
plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )

plt.xlabel("ωs")
plt.ylabel("dφ(ωs)")
plt.legend()
plt.axhline(y = 0, color='k', linestyle='dotted')
plt.grid(True)

# %%
j = 1
i = 0
plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 1
plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 2
plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 3
plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 4
plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )


plt.xlabel("ωs")
plt.ylabel("dφ(ωs)")
plt.axhline(y = 0, color='k', linestyle='dotted')
plt.legend()
plt.grid(True)

# %%
x = np.linspace(-20, 20, 10000)
j = 1
i = 0
plt.plot(x, φ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
j = 2
i = 0
plt.plot(x, φ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
i = 1
plt.plot(x, φ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))
i = 2
plt.plot(x, φ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])))

plt.xlabel("ωs")
plt.ylabel("φ(ωs)")
plt.legend()
plt.grid(True)

# %%
x = np.linspace(-20, 20, 10000)
j = 2
i = 0
plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 1
plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 2
plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 3
plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )
i = 4
plt.plot(x, dφ(x), label=('α = ' + str(α[j]) + ' γ = ' + str(γ[i])) )

plt.xlabel("ωs")
plt.ylabel("dφ(ωs)")
plt.legend()
plt.axhline(y = 0, color='k', linestyle='dotted')
plt.grid(True)

# %%
α = np.linspace(0, 15, 1000)
γ = np.linspace(0, 3.5, 500)
x = np.linspace(-10, -0.0001, 100)
arr = []

#dφ = lambda ωs: - (γ[i] + α[j] * ωs) / (γ[i] +  ωs**2) - T
for αi in α:
    subarr = []
    for γi in γ:
        val = 0
        for i in x:
            if -(γi + αi * i) / (γi**2 +  i**2) - T >= 0:
                val = 1
                break
        subarr.append(val)
    arr.append(subarr)

# %%
plt.imshow(arr, cmap='gray', extent=[0, 3.5, 0, 15],  origin='lower', aspect='auto')
#plt.imshow(arr, cmap='gray')

plt.xlabel("γ")
plt.ylabel("α")

plt.text(4, 8, 'Белый\n- есть пересечения\nпроизводной с нулем\n\nЧерный\n- нет пересечений\nпроизводной с нулем', bbox={'facecolor': 'white', 'pad': 5})
# Out:
# Text(4, 8, 'Белый\n- есть пересечения\nпроизводной с нулем\n\nЧерный\n- нет пересечений\nпроизводной с нулем')

# %%
from sympy import solve, Poly, Eq, Function, exp, sqrt
from sympy import Symbol, init_printing
init_printing()

γ = Symbol('γ')
α = Symbol('α')
ϕ = Symbol('ϕ')
ω = Symbol('ω')
T = Symbol('T')
solve( ϕ + (ω*α + γ)/(γ**2 + ω**2) + T, ω)
# Out:
# ⎡        _____________________________________________________   ⎛       _____
# ⎢       ╱      2  2        2              2      2  2            ⎜      ╱
# ⎢-α + ╲╱  - 4⋅T ⋅γ  - 8⋅T⋅γ ⋅ϕ - 4⋅T⋅γ + α  - 4⋅γ ⋅ϕ  - 4⋅γ⋅ϕ   -⎝α + ╲╱  - 4⋅
# ⎢─────────────────────────────────────────────────────────────, ──────────────
# ⎣                          2⋅(T + ϕ)
#
# ________________________________________________⎞ ⎤
#  2  2        2              2      2  2         ⎟ ⎥
# T ⋅γ  - 8⋅T⋅γ ⋅ϕ - 4⋅T⋅γ + α  - 4⋅γ ⋅ϕ  - 4⋅γ⋅ϕ ⎠ ⎥
# ──────────────────────────────────────────────────⎥
#              2⋅T + 2⋅ϕ                            ⎦

# %%
init_printing(pretty_print=False)
solve(  (ω*α + γ)/(γ**2 + ω**2) + 2, ω)
# Out:
# [-α/4 - sqrt(α**2 - 16*γ**2 - 8*γ)/4, -α/4 + sqrt(α**2 - 16*γ**2 - 8*γ)/4]

# %%
init_printing(pretty_print=True)
solve( 2*(γ**2 + (-α/4 - sqrt(α**2 - 16*γ**2 - 8*γ)/4)**2 )+ α * (-α/4 - sqrt(α**2 - 16*γ**2 - 8*γ)/4) + γ)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-39-e09b90a46b64> in <module>
#       1 init_printing(pretty_print=True)
# ----> 2 solve( 2*(γ**2 + (-α/4 - sqrt(α**2 - 16*γ**2 - 8*γ)/4)**2 )+ α * (-α/4 - sqrt(α**2 - 16*γ**2 - 8*γ)/4) + γ)
#
# ~\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#    1092     ###########################################################################
#    1093     if bare_f:
# -> 1094         solution = _solve(f[0], *symbols, **flags)
#    1095     else:
#    1096         solution = _solve_system(f, symbols, **flags)
#
# ~\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1363             return result
#    1364         else:
# -> 1365             raise NotImplementedError(not_impl_msg % f)
#    1366     symbol = symbols[0]
#    1367
#
# ...

# %%
init_printing(pretty_print=False)
solve( T*(γ**2 + ((-α - sqrt(-4*T**2*γ**2 - 4*T*γ + α**2)) /(2*T))**2) + α*(-α - sqrt(-4*T**2*γ**2 - 4*T*γ + α**2))/(2*T) + γ, α)
# Out:
# []

# %%
init_printing(pretty_print=True)
solve(-T*γ**2 - T - γ,γ)
# Out:
# ⎡   __________       ⎛   __________    ⎞ ⎤
# ⎢  ╱        2        ⎜  ╱        2     ⎟ ⎥
# ⎢╲╱  1 - 4⋅T   - 1  -⎝╲╱  1 - 4⋅T   + 1⎠ ⎥
# ⎢─────────────────, ─────────────────────⎥
# ⎣       2⋅T                  2⋅T         ⎦

# %%
init_printing(pretty_print=False)
solve(-(α * ω + γ) / (γ**2 + ω**2 ) - T, ω)
# Out:
# [(-α + sqrt(-4*T**2*γ**2 - 4*T*γ + α**2))/(2*T), -(α + sqrt(-4*T**2*γ**2 - 4*T*γ + α**2))/(2*T)]

# %%
α = 5
γ = 0.5
T = 2
import math
print((-α + math.sqrt(-4*T**2*γ**2 - 4*T*γ + α**2))/(2*T),'\n' , -(α + math.sqrt(-4*T**2*γ**2 - 4*T*γ + α**2))/(2*T))
# Out:
# -0.21922359359558485
#  -2.2807764064044154

# %%
solve(-α/4 - sqrt(α**2 - 16*γ**2 - 8*γ)/4)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-42-5c37cd8a0d95> in <module>
# ----> 1 solve(-α - sqrt(α**2 - 16*γ**2 - 8*γ))
#
# ~\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#    1092     ###########################################################################
#    1093     if bare_f:
# -> 1094         solution = _solve(f[0], *symbols, **flags)
#    1095     else:
#    1096         solution = _solve_system(f, symbols, **flags)
#
# ~\Anaconda3\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1363             return result
#    1364         else:
# -> 1365             raise NotImplementedError(not_impl_msg % f)
#    1366     symbol = symbols[0]
#    1367
#
# NotImplementedError: No algorithms are implemented to solve equation -α - sqrt(α**2 - 16*γ**2 - 8*γ)
