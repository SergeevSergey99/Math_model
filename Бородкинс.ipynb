# %%
import numpy as np
import os
from matplotlib import pylab as plt
# %matplotlib inline

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False
N = 78
data = []
x = [] #длина волны
y = [] #интенсивность
T = [[0 for i in range(N)] for j in range(52)]
# распечатать все файлы и папки рекурсивно
for dirpath, dirnames, filenames in os.walk("C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/"):
    # перебрать файлы
    cnt = 5
    k = 0
    for filename in filenames:
        if(filename == 'lab2_izm-checkpoint.ipynb' or filename == 'lab2_izm.ipynb'): continue
        print("Файл:", os.path.join(dirpath, filename))
        
        with open(os.path.join(dirpath, filename),'r') as f:
            for line in f:
                for word in line.split():
                    word = word.replace(",", ".")
                    if (is_number(word)):
                        data.append(float(word))
            for i in range(1,len(data),2): 
                T[int(k)][int(data[i-1])] = data[i]
                x.append(data[i-1])
                y.append(data[i])
#            x = x[1300:1600]
#            y = y[1300:1600]
#            print("x = ", x)
#            print("y = ", y)
#            T.append(y)
            '''plt.plot(x, y)
    
            plt.xlabel("Координата элемента ПЗС линейки отн. ед.")
            plt.ylabel("Интенсивность отн. ед.")
            plt.grid()
            plt.savefig(filename + ".png")
            plt.show()
            '''
            '''
            cnt += 1
            if cnt >= 5:
              plt.plot(x[700:900], y[700:900])
              plt.show()
              cnt = 0
            '''
            #вот тут у нас есть массив х и у, надо построить график
            
            print(len(x), ' ', len(y))
            #print(x[0], ' ', y[0])
            #print(x[3647], ' ', y[3647])
            
            k+=1
                
            data = []
            x = []
            y = []
        print (' ')
print(T)
from mpl_toolkits.mplot3d.axes3d import Axes3D
y = np.arange(0, 52, 1)
x = np.arange(0, N, 1)
xs, ys = np.meshgrid(x, y)
zs = np.array(T)
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(xs,ys,zs, rstride=1, cstride=1,cmap='hot')

ax.xlabel("Координата элемента ПЗС линейки отн. ед.")
ax.ylabel("Интенсивность отн. ед.")
ax.zlabel("Номер замера от 25 до 150 A")
plt.show()
#f.close()
# Out:
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/100 А 15 С filter.DAT
# 68   68
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/100 А 20 С filter.DAT
# 0   0
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/100 А 25 С filter.DAT
# 71   71
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/110 А 15 С filter.DAT
# 71   71
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/110 А 20 С filter.DAT
# 75   75
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/110 А 25 С filter.DAT
# 69   69
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/120 А 15 С filter.DAT
# 69   69
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/120 А 20 С filter.DAT
# 68   68
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/120 А 25 С filter.DAT
# 68   68
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/130 А 15 С filter.DAT
# 69   69
#
# ...

# %%
float("69.31")
# Out:
# 69.31

# %%
len(T)
# Out:
# 52

# %%
len(x)
# Out:
# 70

# %%
len(y)
# Out:
# 51

# %%
plt.imshow(T, cmap='hot', extent=[0,78,150,25])

#plt.ylim(25, 100)
#plt.yticks(np.arange(25, 150, 5.0))
#plt.axis('scaled')
plt.xlabel('Координата элемента ПЗС линейки отн. ед.')
plt.ylabel('Сила тока А')
plt.colorbar()

# %%
import numpy as np
import os
from matplotlib import pylab as plt
# %matplotlib inline

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False
N = 78
M = 14
data = []
x = [] #длина волны
y = [] #интенсивность
T = [[0 for i in range(N)] for j in range(M)]
# распечатать все файлы и папки рекурсивно
for dirpath, dirnames, filenames in os.walk("C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/"):
    # перебрать файлы
    cnt = 5
    k = 0
    for filename in filenames:
        if(filename == 'lab2_izm-checkpoint.ipynb' or filename == 'lab2_izm.ipynb'): continue
        print("Файл:", os.path.join(dirpath, filename))
        
        with open(os.path.join(dirpath, filename),'r') as f:
            for line in f:
                for word in line.split():
                    word = word.replace(",", ".")
                    if (is_number(word)):
                        data.append(float(word))
            if len(filename.split(" "))>2 and len(data)>0 and int(filename.split(" ")[2]) == 25:  
                for i in range(1,len(data),2): 
                    T[int(k)][int(data[i-1])] = data[i]
                k+=1
#                x.append(data[i-1])
#                y.append(data[i])
#            x = x[1300:1600]
#            y = y[1300:1600]
#            print("x = ", x)
#            print("y = ", y)
#            T.append(y)
#            plt.plot(x, y)
    
#            plt.xlabel("Координата элемента ПЗС линейки отн. ед.")
#            plt.ylabel("Интенсивность отн. ед.")
#            plt.grid()
#            plt.savefig(filename + ".png")
#            plt.show()
              
            '''
            cnt += 1
            if cnt >= 5:
              plt.plot(x[700:900], y[700:900])
              plt.show()
              cnt = 0
            '''
            #вот тут у нас есть массив х и у, надо построить график
            
            #print(len(x), ' ', len(y))
            #print(x[0], ' ', y[0])
            #print(x[3647], ' ', y[3647])
            
            
                
            data = []
            x = []
            y = []
        print (' ')
#print(T)
from mpl_toolkits.mplot3d.axes3d import Axes3D
y = np.arange(0, M, 1)
x = np.arange(0, N, 1)
xs, ys = np.meshgrid(x, y)
zs = np.array(T)
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(xs,ys,zs, rstride=1, cstride=1,cmap='hot')
ax.set_xlabel("Координата элемента ПЗС линейки отн. ед.", linespacing=3.2)
ax.set_ylabel("Измеряемый слой №", linespacing=3.2)
ax.set_zlabel("Интенсивность отн. ед.", linespacing=3.2)

plt.show()
#f.close()
# Out:
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/100 А 15 С filter.DAT
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/100 А 20 С filter.DAT
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/100 А 25 С filter.DAT
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/110 А 15 С filter.DAT
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/110 А 20 С filter.DAT
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/110 А 25 С filter.DAT
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/120 А 15 С filter.DAT
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/120 А 20 С filter.DAT
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/120 А 25 С filter.DAT
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/130 А 15 С filter.DAT
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/Лаба 3 Я, Ч, Х, Т/130 А 20 С filter.DAT
#
# ...

# %%
import numpy as np
import os
from matplotlib import pylab as plt
import pylab as plb
from scipy.optimize import curve_fit
from scipy import asarray as ar,exp
# %matplotlib inline

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False
#N = 78
data = []
x = [] #длина волны
y = [] #интенсивность
X = []
Y1 = []
Y2 = []
Y3 = []
Y4 = []
Y5 = []
#T = [[0 for i in range(N)] for j in range(52)]
# распечатать все файлы и папки рекурсивно

def gaus(x, a, x0,sigma):
    return a * np.exp(-(x-x0)**2 / (2 * sigma**2))

for dirpath, dirnames, filenames in os.walk("C:/Users/MSI/Documents/ITMO 4th cource/L3430_Kopytov_Cheiotarev_Berdyugina_Yushkevich/"):
    # перебрать файлы
    cnt = 5
    k = 0
    for filename in filenames:
        if(filename == 'lab2_izm-checkpoint.ipynb' or filename == 'lab2_izm.ipynb'): continue
        print("Файл:", os.path.join(dirpath, filename))
        
        with open(os.path.join(dirpath, filename),'r') as f:
            for line in f:
                for word in line.split():
                    word = word.replace(",", ".")
                    if (is_number(word)):
                        data.append(float(word))
            for i in range(1,len(data),2): 
                #T[int(k)][int(data[i-1])] = data[i]
                x.append(data[i-1])
                y.append(data[i])
            x = np.array(x[1390:1480])
            y = np.array(y[1390:1480])
            y = y - (np.min(y))# + np.max(y[:10]))/2
#            print("x = ", x)
#            print("y = ", y)
#            T.append(y)
            
            plt.plot(x,y,'b+:',label='data')
            try:
                n = len(x)                          #the number of data
                mean = sum(x * y) / sum(y)
                sigma = np.sqrt(sum(y * (x - mean)**2) / sum(y))



                popt,pcov = curve_fit(gaus, x, y, p0=[max(y), mean, sigma])


                G = gaus(x,*popt)
                
                avrVal =  (np.max(G)+np.min(G)) / 2
                start = -1
                finish = -1
                gi = 0
                for g in G:
                    if start != -1 and finish == -1:
                        if g < avrVal:
                            finish = gi
                    
                    if start == -1:
                        if g >= avrVal:
                            start = gi
                    gi += 1
                print(x[start])
                print(x[finish])
                plt.plot(x,G,'ro:',label='gauss fit')
                
                plt.hlines(y = avrVal, xmin=x[start], xmax=x[finish],  color='k')
                print(x[finish] - x[start])
                
                if(int(dirpath[-2:]) == 15):
                    Y1.append(x[np.argmax(G)])
                    X.append(int(filename[:-4]))
                if(int(dirpath[-2:]) == 20):
                    Y2.append(x[np.argmax(G)])
                if(int(dirpath[-2:]) == 25):
                    Y3.append(x[np.argmax(G)])
                if(int(dirpath[-2:]) == 30):
                    Y4.append(x[np.argmax(G)])
                if(int(dirpath[-2:]) == 35):
                    Y5.append(x[np.argmax(G)])
                '''
                if(int(dirpath[-2:]) == 15):
                    Y1.append(x[finish] - x[start])
                    X.append(int(filename[:-4]))
                if(int(dirpath[-2:]) == 20):
                    Y2.append(x[finish] - x[start])
                if(int(dirpath[-2:]) == 25):
                    Y3.append(x[finish] - x[start])
                if(int(dirpath[-2:]) == 30):
                    Y4.append(x[finish] - x[start])
                if(int(dirpath[-2:]) == 35):
                    Y5.append(x[finish] - x[start])
                '''
                
            except:
                print("exeption")
            plt.legend()
            plt.title('Апроксимация при I = ' + filename[:-4] + ' А и Т = ' +dirpath[-2:])
            plt.xlabel('Длина волны нм')
            plt.ylabel('Интенсивность')
    
            #plt.xlabel("Координата элемента ПЗС линейки отн. ед.")
            #plt.ylabel("Интенсивность отн. ед.")
            plt.grid()
            plt.savefig('I = ' + filename[:-4] + ' А и Т = ' +dirpath[-2:] + ".png")
            plt.show()
            k+=1
            data = []
            x = []
            y = []
        print (' ')
#print(T)
#from mpl_toolkits.mplot3d.axes3d import Axes3D
#y = np.arange(0, 52, 1)
#x = np.arange(0, N, 1)
#xs, ys = np.meshgrid(x, y)
#zs = np.array(T)
#fig = plt.figure()
#ax = Axes3D(fig)
#ax.plot_surface(xs,ys,zs, rstride=1, cstride=1,cmap='hot')

#ax.xlabel("Координата элемента ПЗС линейки отн. ед.")
#ax.ylabel("Интенсивность отн. ед.")
#ax.zlabel("Номер замера от 25 до 150 A")
#plt.show()
#f.close()
# Out:
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/L3430_Kopytov_Cheiotarev_Berdyugina_Yushkevich/L3430 Копытов Чеьотарев Бердюгина Юшкевич\15\1000.DAT
# 808.081
# 809.426
# 1.3450000000000273
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/L3430_Kopytov_Cheiotarev_Berdyugina_Yushkevich/L3430 Копытов Чеьотарев Бердюгина Юшкевич\15\1100.DAT
# 807.947
# 808.888
# 0.9410000000000309
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/L3430_Kopytov_Cheiotarev_Berdyugina_Yushkevich/L3430 Копытов Чеьотарев Бердюгина Юшкевич\15\1200.DAT
# 808.081
# 808.888
# 0.8070000000000164
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/L3430_Kopytov_Cheiotarev_Berdyugina_Yushkevich/L3430 Копытов Чеьотарев Бердюгина Юшкевич\15\1300.DAT
# 808.081
# 809.426
# 1.3450000000000273
#
# Файл: C:/Users/MSI/Documents/ITMO 4th cource/L3430_Kopytov_Cheiotarev_Berdyugina_Yushkevich/L3430 Копытов Чеьотарев Бердюгина Юшкевич\15\1400.DAT
# 808.216
# 809.561
# 1.3450000000000273
#
# ...

# %%
X = X[-6:]+X[:12]
Y1 = Y1[-6:]+Y1[:12]
Y2 = Y2[-6:]+Y2[:12]
Y3 = Y3[-6:]+Y3[:12]
Y4 = Y4[-6:]+Y4[:12]
Y5 = Y5[-6:]+Y5[:12]

# %%
plt.plot(X,Y1,label='T = 15')
plt.plot(X,Y2,label='T = 20')
plt.plot(X,Y3,label='T = 25')
plt.plot(X,Y4,label='T = 30')
plt.plot(X,Y5,label='T = 35')
plt.legend()
plt.grid()
plt.show()

# %%
s = 1
p = plt.plot(X[s:],Y1[s:],label='T = 15', linestyle='dotted')
f = np.poly1d(np.polyfit(X[s:],Y1[s:], 1))
plt.plot(X[s:], f(X[s:]), c=p[0].get_c())
p = plt.plot(X[s:],Y2[s:],label='T = 20', linestyle='dotted')
f = np.poly1d(np.polyfit(X[s:],Y2[s:], 1))
plt.plot(X[s:], f(X[s:]), c=p[0].get_c())
p = plt.plot(X[s:],Y3[s:],label='T = 25', linestyle='dotted')
f = np.poly1d(np.polyfit(X[s:],Y3[s:], 1))
plt.plot(X[s:], f(X[s:]), c=p[0].get_c())
p = plt.plot(X[s:],Y4[s:],label='T = 30', linestyle='dotted')
f = np.poly1d(np.polyfit(X[s:],Y4[s:], 1))
plt.plot(X[s:], f(X[s:]), c=p[0].get_c())
p = plt.plot(X[s:],Y5[s:],label='T = 35', linestyle='dotted')
f = np.poly1d(np.polyfit(X[s:],Y5[s:], 1))
plt.plot(X[s:], f(X[s:]), c=p[0].get_c())

plt.xlabel('Сила тока мА')
plt.ylabel('λ нм')
plt.legend()
plt.grid()
plt.show()

# %%
print(X[-6:]+X[:12] )
# Out:
# [400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100]

# %%
import numpy as np
import os
from matplotlib import pylab as plt

I = 50
t = 0.25
g = 20

T = [30,
     32,
     34,
     36,
     38,
     40,
     42,
     44,
     46,
     48,
     50
     ]
dx = [254,
     254.7187,
     257.7656,
      259.5937,
      257.5156,
      256.5156,
      257,
      258.5,
      259.5,
      258.5,
      260
     ]
dy = [3.225,
     3.665,
     4.062,
     4.465,
     4.7875,
     5.25,
     5.5875,
     6.025,
     6.3875,
     6.775,
     7.275
     ]
p = plt.plot(T, dy, linestyle='dotted')

f = np.poly1d(np.polyfit(T,dy, 1))
plt.plot(T, f(T), c=p[0].get_c())
plt.grid()
plt.xlabel('Амплитуда импульса В')
plt.ylabel('Длительность импульса мкс')
plt.show()

# %%
I = 40
t = 0.25
g = 20

T = [20,
     22,
     24,
     26,
     28,
     30,
     32,
     34,
     36,
     38,
     40
     ]
dx = [259.5,
     258.5,
     258,
     258,
     258,
     254.5,
     256.9,
     258,
     257.5,
     256,
     256
     ]
dy = [5.3,
     5.125,
     5,
     4.85,
     4.775,
     4.825,
     4.8187,
     4.775,
     4.6937,
     4.5875,
     4.55
     ]
p = plt.plot(T, dy, linestyle='dotted')

f = np.poly1d(np.polyfit(T,dy, 1))
plt.plot(T, f(T), c=p[0].get_c())
plt.grid()
plt.xlabel('Температура °С')
plt.ylabel('Амплитуда импульса В')
plt.show()
