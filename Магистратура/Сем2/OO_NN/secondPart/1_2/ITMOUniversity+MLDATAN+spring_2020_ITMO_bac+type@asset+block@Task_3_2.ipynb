# %% [markdown]
# # Пример восстановления исходного изображения размером 200х200 пикселей по первым десяти ГК, если известны матрица счётов и матрица весов.

# %% [markdown]
# Для восстановления исходного изображения воспользуемся матрицами счётов и весов.

# %%
#Импорт библиотеки Numpy
import numpy as np 
#Создание массивов Numpy на основе матриц счётов и весов
scores = np.genfromtxt('X_reduced_401.csv', delimiter=';')
loadings = np.genfromtxt('X_loadings_401.csv', delimiter=';')

# %% [markdown]
# Найдем матрицу восстановленных данных как произведение матрицы счётов на транспонированную матрицу весов.

# %%
values = np.dot(scores,loadings.T)

# %% [markdown]
# Создадим изображение на основе полученных значений при помощи библиотеки matplotlib

# %%
#Импорт библиотеки
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
#Создание изображения
plt.imshow(values, cmap='Greys_r')

# %% [markdown]
# Для сравнения, ниже представлено оригинальное изображение

# %%
original = np.genfromtxt('X_original_401.csv', delimiter=';')
plt.imshow(original, cmap='Greys_r')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\Users\D899~1\AppData\Local\Temp/ipykernel_30704/3593887029.py in <module>
# ----> 1 original = np.genfromtxt('X_original_401.csv', delimiter=';')
#       2 plt.imshow(original, cmap='Greys_r')
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, like)
#    1789             fname = os_fspath(fname)
#    1790         if isinstance(fname, str):
# -> 1791             fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1792             fid_ctx = contextlib.closing(fid)
#    1793         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(path, mode, destpath, encoding, newline)
#     192
#     193     ds = DataSource(destpath)
# --> 194     return ds.open(path, mode, encoding=encoding, newline=newline)
#     195
#     196
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\_datasource.py in open(self, path, mode, encoding, newline)
#     529                                       encoding=encoding, newline=newline)
#     530         else:
# --> 531             raise IOError("%s not found." % path)
#     532
#     533
#
# OSError: X_original_401.csv not found.
