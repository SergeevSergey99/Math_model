# %%
! pip install -q catsim
# Out:
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\ProgramData\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
from catsim.cat import generate_item_bank
from catsim import plot

# %%
from catsim.initialization import RandomInitializer
from catsim.estimation import NumericalSearchEstimator
from catsim.simulation import Simulator
from catsim.stopping import MaxItemStopper

# %%
from catsim.selection import RandomSelector
from catsim.selection import UrrySelector
from catsim.selection import MaxInfoSelector

# %% [markdown]
# # Задание №1

# %% [markdown]
# Реализуйте цикл тестирования, состоящий из инициализации, (случайного) выбора заданий, сбора ответа, обновления оценки для уровня подготовленности и проверки критерия завершения. Для обновления оценки используйте результаты лабораторной работы 1.

# %%
simulator = Simulator(generate_item_bank(n=300, itemtype='2PL'), 
                      1000)
simulator

# %%
initializer = RandomInitializer()
random_selector = RandomSelector() # Случайный выбор заданий
estimator = NumericalSearchEstimator()
stopper = MaxItemStopper(20)

simulator.simulate(initializer, 
                   random_selector, 
                   estimator, 
                   stopper)
simulator

# %%
plot.test_progress(simulator=simulator, 
                   index=0)

# %% [markdown]
# # Задание №2

# %% [markdown]
# Сравните разные методы рекомендации заданий: случайный выбор и адаптивный выбор с помощью максимальной информации Фишера. Задайте точность оценивания, равную 0.1. Сколько заданий необходимо предъявить пользователю для достижения требуемой точности в зависимости от его уровня подготовленности?

# %%
simulator = Simulator(generate_item_bank(n=300,itemtype='2PL'), 
                      1000) # 1000 репликаций?

initializer = RandomInitializer()
random_selector = RandomSelector() # Случайный выбор заданий
estimator = NumericalSearchEstimator(precision=2) # задаем точность
stopper = MaxItemStopper(20)

simulator.simulate(initializer, 
                   random_selector, 
                   estimator, 
                   stopper)

plot.test_progress(simulator=simulator, 
                   index=0)

# %%
simulator = Simulator(generate_item_bank(n=300,itemtype='2PL'), 
                      1000) # 1000 репликаций?

initializer = RandomInitializer()
random_selector = MaxInfoSelector() # Случайный выбор заданий
estimator = NumericalSearchEstimator(precision=2) # задаем точность
stopper = MaxItemStopper(20)

simulator.simulate(initializer, 
                   random_selector, 
                   estimator, 
                   stopper)

plot.test_progress(simulator=simulator, 
                   index=0)

# %%
simulator = Simulator(generate_item_bank(n=3000,itemtype='2PL'),
                      1000) # 1000 репликаций?

initializer = RandomInitializer()
random_selector = MaxInfoSelector() # Случайный выбор заданий
estimator = NumericalSearchEstimator(precision=2) # задаем точность
stopper = MaxItemStopper(200)

simulator.simulate(initializer,
                   random_selector,
                   estimator,
                   stopper)

plot.test_progress(simulator=simulator,
                   index=0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\D899~1\AppData\Local\Temp/ipykernel_35344/2117839575.py in <module>
#       7 stopper = MaxItemStopper(200)
#       8
# ----> 9 simulator.simulate(initializer,
#      10                    random_selector,
#      11                    estimator,
#
# C:\ProgramData\anaconda3\lib\site-packages\catsim\simulation.py in simulate(self, initializer, selector, estimator, stopper, verbose)
#     481
#     482                 # estimate the new theta using the given estimator
# --> 483                 est_theta = self._estimator.estimate(current_examinee)
#     484
#     485                 # count occurrences of this item in all tests
#
# C:\ProgramData\anaconda3\lib\site-packages\catsim\estimation.py in estimate(self, index, items, administered_items, response_vector, est_theta, **kwargs)
#     151                 bounds=(lower_bound, upper_bound),
#     152                 method=self.__search_method,
# --> 153                 args=(response_vector, items[administered_items]),
#     154                 tol=self._epsilon if self.__search_method != "bounded" else None,
#     155             )
#
# KeyboardInterrupt:
